# %% [markdown]
# <a href="https://colab.research.google.com/github/nathgc/Machine-Learning-Estudos/blob/main/Exemplos_MLP/MLP_MNIST_Keras_new.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **JUPYTER NOTEBOOK FOR A MLP LEARNING MNIST NUMBERS from 0 to 9 **

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
from keras.datasets import mnist

# %%
# !pip install keras.utils
# Out:
# Collecting keras.utils
#   Downloading keras-utils-1.0.13.tar.gz (2.4 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from keras.utils) (2.13.1)
# Building wheels for collected packages: keras.utils
#   Building wheel for keras.utils (setup.py) ... done
#   Created wheel for keras.utils: filename=keras_utils-1.0.13-py3-none-any.whl size=2632 sha256=b2c5f25fa06e146fec71ade9d8c9eed6772dc7c52df7c0fc0b66ab5da53c43d4
#   Stored in directory: /root/.cache/pip/wheels/5c/c0/b3/0c332de4fd71f3733ea6d61697464b7ae4b2b5ff0300e6ca7a
# Successfully built keras.utils
# Installing collected packages: keras.utils
# Successfully installed keras.utils-1.0.13

# %%
import keras.utils

# %% [markdown]
# **Define the network hyperparameters**

# %%
# Trainign batch size
batch_size = 128
# Number of training epochs
epochs = 50
# Fraction of the training data to be used as validation
val_split = 0.3
# Number of classes ( multi-classification )
nb_classes = 10
# Learning rate
lr=0.1

# %% [markdown]
# **Load the MNIST dataset and format it for train and validation**

# %%
# Load MNIST dataset (28x28 pixel images)
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = X_train.reshape(60000, 784)
X_test = X_test.reshape(10000, 784)
X_train = X_train.astype('float32')
X_test = X_test.astype('float32')
X_train /= 255
X_test /= 255
Y_Train = keras.utils.to_categorical(y_train, nb_classes)
Y_Test = keras.utils.to_categorical(y_test, nb_classes)

# %% [markdown]
# Link explicando erro com np_utils
#
# https://stackoverflow.com/questions/45149341/importerror-cannot-import-name-np-utils

# %% [markdown]
# **Define the MLP achitecture using KERAS sequential API**

# %%
# Multilayer Perceptron model
model = Sequential()
model.add(Dense(input_dim=784, activation="relu", units=100, kernel_initializer="normal"))
model.add(Dense(activation="relu", units=50, kernel_initializer="normal")) # after first layer no need to specify input_dim
model.add(Dense(activation="relu", units=25, kernel_initializer="normal")) # after first layer no need to specify input_dim
model.add(Dense(activation="sigmoid", units=10, kernel_initializer="normal"))
model.compile(optimizer=SGD(lr=lr), loss='mean_squared_error', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 50)                5050
#
#  dense_2 (Dense)             (None, 25)                1275
#
#  dense_3 (Dense)             (None, 10)                260
#
# =================================================================
# Total params: 85085 (332.36 KB)
# Trainable params: 85085 (332.36 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# **Train the MLP**

# %%
# Train
history = model.fit(X_train, Y_Train, validation_split=val_split, epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.2428 - accuracy: 0.1341 - val_loss: 0.2361 - val_accuracy: 0.1373
# Epoch 2/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.2295 - accuracy: 0.1399 - val_loss: 0.2230 - val_accuracy: 0.1449
# Epoch 3/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.2165 - accuracy: 0.1499 - val_loss: 0.2099 - val_accuracy: 0.1532
# Epoch 4/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2028 - accuracy: 0.1533 - val_loss: 0.1952 - val_accuracy: 0.1541
# Epoch 5/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1858 - accuracy: 0.1307 - val_loss: 0.1750 - val_accuracy: 0.1107
# Epoch 6/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1595 - accuracy: 0.1010 - val_loss: 0.1413 - val_accuracy: 0.1006
# Epoch 7/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1219 - accuracy: 0.0987 - val_loss: 0.1063 - val_accuracy: 0.1006
# Epoch 8/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0991 - accuracy: 0.0987 - val_loss: 0.0949 - val_accuracy: 0.1006
# Epoch 9/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0934 - accuracy: 0.0994 - val_loss: 0.0925 - val_accuracy: 0.1036
# Epoch 10/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0922 - accuracy: 0.1308 - val_loss: 0.0918 - val_accuracy: 0.1710
# Epoch 11/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.0918 - accuracy: 0.1385 - val_loss: 0.0916 - val_accuracy: 0.1080
# Epoch 12/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0917 - accuracy: 0.1143 - val_loss: 0.0915 - val_accuracy: 0.1079
# Epoch 13/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0916 - accuracy: 0.1143 - val_loss: 0.0915 - val_accuracy: 0.1079
# Epoch 14/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0915 - accuracy: 0.1143 - val_loss: 0.0914 - val_accuracy: 0.1079
# Epoch 15/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0915 - accuracy: 0.1143 - val_loss: 0.0914 - val_accuracy: 0.1079
# Epoch 16/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0915 - accuracy: 0.1143 - val_loss: 0.0914 - val_accuracy: 0.1079
# Epoch 17/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0915 - accuracy: 0.1143 - val_loss: 0.0914 - val_accuracy: 0.1079
# Epoch 18/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0914 - accuracy: 0.1143 - val_loss: 0.0914 - val_accuracy: 0.1079
# Epoch 19/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0914 - accuracy: 0.1143 - val_loss: 0.0913 - val_accuracy: 0.1079
# Epoch 20/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0914 - accuracy: 0.1143 - val_loss: 0.0913 - val_accuracy: 0.1079
# Epoch 21/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.0914 - accuracy: 0.1143 - val_loss: 0.0913 - val_accuracy: 0.1079
# Epoch 22/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0914 - accuracy: 0.1143 - val_loss: 0.0913 - val_accuracy: 0.1079
# Epoch 23/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0914 - accuracy: 0.1143 - val_loss: 0.0913 - val_accuracy: 0.1079
# Epoch 24/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0914 - accuracy: 0.1143 - val_loss: 0.0913 - val_accuracy: 0.1079
# Epoch 25/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0913 - accuracy: 0.1143 - val_loss: 0.0913 - val_accuracy: 0.1079
# Epoch 26/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0913 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 27/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0913 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 28/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0913 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 29/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0913 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 30/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.0913 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 31/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0913 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 32/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 33/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 34/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 35/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 36/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 37/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 38/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 39/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 40/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 41/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0912 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 42/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 43/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 44/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0911 - val_accuracy: 0.1079
# Epoch 45/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0910 - val_accuracy: 0.1079
# Epoch 46/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0910 - val_accuracy: 0.1079
# Epoch 47/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0910 - val_accuracy: 0.1079
# Epoch 48/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0910 - val_accuracy: 0.1079
# Epoch 49/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0910 - val_accuracy: 0.1079
# Epoch 50/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0910 - val_accuracy: 0.1079

# %% [markdown]
# **Evaluate the MLP performance**

# %%
# Evaluate
evaluation = model.evaluate(X_test, Y_Test, verbose=1)
print('Summary: Loss over the test dataset: %.2f, Accuracy: %.2f' % (evaluation[0], evaluation[1]))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0910 - accuracy: 0.1135
# Summary: Loss over the test dataset: 0.09, Accuracy: 0.11

# %% [markdown]
# **Plot the training and validation performances**

# %%
# Training History Visualization

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# No código acima foi preciso substituir "acc" por "accuracy"

# %%
Nplot = 20
plt.figure(figsize=(10,10))
Y = model.predict(X_test, batch_size=64)
#Y=model.predict(X_test)
Y=Y*10.
print(Y.shape)
for n in range(Nplot):
  X=X_test[n,:]
  ax = plt.subplot(4, 5, n+1)
  plt.imshow(X.reshape(28,28))
  plt.axis('off')
  index = np.argmax(Y[n])
  plt.title('Prediction='+str(index))
plt.show()
# Out:
# 157/157 [==============================] - 0s 2ms/step
# (10000, 10)

# %% [markdown]
# **Exercises:**
#
# ---
#
#
# **Question 1**: What happens if you increase/decrease the number of hidden layers?
#
#
# **Question 2:** What happens if you increase/decrease the number of nodes per hidden layer?
#
# **Question 3:** What happens if you increase/decrease the learning rate ?
#
# **Question 4:** What happens if you increase/decrease the number of training epochs  ?
#
# **Question 5:** What happens if you increase/decrease the training batch size ?
#
# **Question 6:** What happens if you use the ReLU activation function in the hidden layers ?

# %% [markdown]
# Question 1 :

# %% [markdown]
# Aumentando número de camadas: +3

# %%
# Multilayer Perceptron model
model = Sequential()
model.add(Dense(input_dim=784, activation="relu", units=100, kernel_initializer="normal"))
model.add(Dense(activation="relu", units=50, kernel_initializer="normal")) # after first layer no need to specify input_dim
model.add(Dense(activation="relu", units=25, kernel_initializer="normal")) # after first layer no need to specify input_dim
model.add(Dense(activation="relu", units=25, kernel_initializer="normal"))
model.add(Dense(activation="relu", units=25, kernel_initializer="normal"))
model.add(Dense(activation="relu", units=25, kernel_initializer="normal"))
model.add(Dense(activation="sigmoid", units=10, kernel_initializer="normal"))
model.compile(optimizer=SGD(lr=lr), loss='mean_squared_error', metrics=['accuracy'])
model.summary()
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 100)               78500
#
#  dense_5 (Dense)             (None, 50)                5050
#
#  dense_6 (Dense)             (None, 25)                1275
#
#  dense_7 (Dense)             (None, 25)                650
#
#  dense_8 (Dense)             (None, 25)                650
#
#  dense_9 (Dense)             (None, 25)                650
#
#  dense_10 (Dense)            (None, 10)                260
#
# =================================================================
# Total params: 87035 (339.98 KB)
# Trainable params: 87035 (339.98 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# Train
history = model.fit(X_train, Y_Train, validation_split=val_split, epochs=epochs, batch_size=batch_size, verbose=1)
# Out:
# Epoch 1/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.2433 - accuracy: 0.1130 - val_loss: 0.2367 - val_accuracy: 0.1079
# Epoch 2/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2305 - accuracy: 0.1143 - val_loss: 0.2244 - val_accuracy: 0.1079
# Epoch 3/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.2187 - accuracy: 0.1143 - val_loss: 0.2130 - val_accuracy: 0.1079
# Epoch 4/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.2077 - accuracy: 0.1143 - val_loss: 0.2025 - val_accuracy: 0.1079
# Epoch 5/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1975 - accuracy: 0.1143 - val_loss: 0.1926 - val_accuracy: 0.1079
# Epoch 6/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1879 - accuracy: 0.1143 - val_loss: 0.1833 - val_accuracy: 0.1079
# Epoch 7/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1789 - accuracy: 0.1143 - val_loss: 0.1745 - val_accuracy: 0.1079
# Epoch 8/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1703 - accuracy: 0.1143 - val_loss: 0.1662 - val_accuracy: 0.1079
# Epoch 9/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1622 - accuracy: 0.1143 - val_loss: 0.1583 - val_accuracy: 0.1079
# Epoch 10/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1545 - accuracy: 0.1143 - val_loss: 0.1507 - val_accuracy: 0.1079
# Epoch 11/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1471 - accuracy: 0.1143 - val_loss: 0.1436 - val_accuracy: 0.1079
# Epoch 12/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1402 - accuracy: 0.1143 - val_loss: 0.1368 - val_accuracy: 0.1079
# Epoch 13/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.1337 - accuracy: 0.1143 - val_loss: 0.1306 - val_accuracy: 0.1079
# Epoch 14/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1277 - accuracy: 0.1143 - val_loss: 0.1249 - val_accuracy: 0.1079
# Epoch 15/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1223 - accuracy: 0.1143 - val_loss: 0.1197 - val_accuracy: 0.1079
# Epoch 16/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1174 - accuracy: 0.1143 - val_loss: 0.1152 - val_accuracy: 0.1079
# Epoch 17/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1131 - accuracy: 0.1143 - val_loss: 0.1112 - val_accuracy: 0.1079
# Epoch 18/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1094 - accuracy: 0.1143 - val_loss: 0.1077 - val_accuracy: 0.1079
# Epoch 19/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1062 - accuracy: 0.1143 - val_loss: 0.1048 - val_accuracy: 0.1079
# Epoch 20/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.1035 - accuracy: 0.1143 - val_loss: 0.1023 - val_accuracy: 0.1079
# Epoch 21/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.1012 - accuracy: 0.1143 - val_loss: 0.1002 - val_accuracy: 0.1079
# Epoch 22/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.0993 - accuracy: 0.1143 - val_loss: 0.0985 - val_accuracy: 0.1079
# Epoch 23/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0978 - accuracy: 0.1143 - val_loss: 0.0971 - val_accuracy: 0.1079
# Epoch 24/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0965 - accuracy: 0.1143 - val_loss: 0.0959 - val_accuracy: 0.1079
# Epoch 25/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0954 - accuracy: 0.1143 - val_loss: 0.0949 - val_accuracy: 0.1079
# Epoch 26/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0945 - accuracy: 0.1143 - val_loss: 0.0941 - val_accuracy: 0.1079
# Epoch 27/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0938 - accuracy: 0.1143 - val_loss: 0.0934 - val_accuracy: 0.1079
# Epoch 28/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0931 - accuracy: 0.1143 - val_loss: 0.0929 - val_accuracy: 0.1079
# Epoch 29/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0926 - accuracy: 0.1143 - val_loss: 0.0924 - val_accuracy: 0.1079
# Epoch 30/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.0922 - accuracy: 0.1143 - val_loss: 0.0920 - val_accuracy: 0.1079
# Epoch 31/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0919 - accuracy: 0.1143 - val_loss: 0.0917 - val_accuracy: 0.1079
# Epoch 32/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0916 - accuracy: 0.1143 - val_loss: 0.0915 - val_accuracy: 0.1079
# Epoch 33/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0913 - accuracy: 0.1143 - val_loss: 0.0912 - val_accuracy: 0.1079
# Epoch 34/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0911 - accuracy: 0.1143 - val_loss: 0.0910 - val_accuracy: 0.1079
# Epoch 35/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0910 - accuracy: 0.1143 - val_loss: 0.0909 - val_accuracy: 0.1079
# Epoch 36/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0908 - accuracy: 0.1143 - val_loss: 0.0908 - val_accuracy: 0.1079
# Epoch 37/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0907 - accuracy: 0.1143 - val_loss: 0.0906 - val_accuracy: 0.1079
# Epoch 38/50
# 329/329 [==============================] - 2s 6ms/step - loss: 0.0906 - accuracy: 0.1143 - val_loss: 0.0905 - val_accuracy: 0.1079
# Epoch 39/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0905 - accuracy: 0.1143 - val_loss: 0.0905 - val_accuracy: 0.1079
# Epoch 40/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0904 - accuracy: 0.1143 - val_loss: 0.0904 - val_accuracy: 0.1079
# Epoch 41/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0904 - accuracy: 0.1143 - val_loss: 0.0903 - val_accuracy: 0.1079
# Epoch 42/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0903 - accuracy: 0.1143 - val_loss: 0.0903 - val_accuracy: 0.1079
# Epoch 43/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0903 - accuracy: 0.1143 - val_loss: 0.0902 - val_accuracy: 0.1079
# Epoch 44/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0902 - accuracy: 0.1143 - val_loss: 0.0902 - val_accuracy: 0.1079
# Epoch 45/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0902 - accuracy: 0.1143 - val_loss: 0.0902 - val_accuracy: 0.1079
# Epoch 46/50
# 329/329 [==============================] - 2s 5ms/step - loss: 0.0902 - accuracy: 0.1143 - val_loss: 0.0902 - val_accuracy: 0.1079
# Epoch 47/50
# 329/329 [==============================] - 2s 7ms/step - loss: 0.0901 - accuracy: 0.1143 - val_loss: 0.0901 - val_accuracy: 0.1079
# Epoch 48/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0901 - accuracy: 0.1143 - val_loss: 0.0901 - val_accuracy: 0.1079
# Epoch 49/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0901 - accuracy: 0.1143 - val_loss: 0.0901 - val_accuracy: 0.1079
# Epoch 50/50
# 329/329 [==============================] - 1s 4ms/step - loss: 0.0901 - accuracy: 0.1143 - val_loss: 0.0901 - val_accuracy: 0.1079

# %%
# Evaluate
evaluation = model.evaluate(X_test, Y_Test, verbose=1)
print('Summary: Loss over the test dataset: %.2f, Accuracy: %.2f' % (evaluation[0], evaluation[1]))
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0901 - accuracy: 0.1135
# Summary: Loss over the test dataset: 0.09, Accuracy: 0.11

# %%
# Training History Visualization

# Plot training & validation accuracy values
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper right')
plt.show()
